# %% [markdown]
# # Capstone Project

# %% [markdown]
# ### Data Visualization

# %%
#Import libraries
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
from nltk.corpus import stopwords

# %%
#Read in 'final_df'
final_df = pd.read_csv("../dataset/final_df.csv")

# %%
#Check shape
final_df.shape
# Out:
# (22153, 9)

# %%
#Check data types
final_df.dtypes
# Out:
# Unnamed: 0                 int64
# tweet_id                   int64
# tweet_posted_on           object
# tweets                    object
# cleaned_tweets            object
# user_location             object
# polarity                   int64
# user_location_cleaned     object
# Unnamed: 0.1             float64
# dtype: object

# %%
#Drop Unnamed: 0 column
final_df.drop(['Unnamed: 0','Unnamed: 0.1'], axis=1, inplace=True)

# %%
#Display first five rows
final_df.head()
# Out:
#               tweet_id            tweet_posted_on  \
# 0  1416181616846811137  2021-07-16 23:43:03+00:00
# 1  1416181380279635970  2021-07-16 23:42:07+00:00
# 2  1416181225979473920  2021-07-16 23:41:30+00:00
# 3  1416180635903868934  2021-07-16 23:39:09+00:00
# 4  1416180231350759425  2021-07-16 23:37:33+00:00
#
#                                               tweets  \
# 0  🏡 #RemoteWork is on the rise &amp; slowly beco...
# 1  Opportunity to join a fantastic team at a hi-t...
# 2  Good news for #JobSeekers open to #RemoteWork!...
# 3  Four Ways to Energize a Post-Pandemic Workforc...
# 4  🚑 These are the tools that will save your #Rem...
#
#                                       cleaned_tweets  \
# 0  rise slowly becoming normal which mean need re...
# 1  opportunity join fantastic team tech fast pace...
# 2  good news open this excellent report from remo...
# 3          four way energize post pandemic workforce
# 4  these tool that will save your google meet too...
#
#                     user_location  polarity user_location_cleaned
# 0                    New York, NY         1                    US
# 1               London | New York         1                    US
# 2  Sydney | Hong Kong | Singapore         1                    HK
# 3                     Chicago, IL         1                    US
# 4                      Duluth, GA         0                    US

# %%
#Check missing values
final_df.isnull().sum()
# Out:
# tweet_id                  0
# tweet_posted_on           0
# tweets                    0
# cleaned_tweets           51
# user_location             1
# polarity                  0
# user_location_cleaned     1
# dtype: int64

# %%
#Check where 'cleaned_tweets' are missing
np.where(final_df['cleaned_tweets'].isnull() == True)
# Out:
# (array([ 4017,  4018,  5236,  5830,  5929,  5997,  6118,  6307,  6308,
#          6797,  7734,  9653,  9864,  9869,  9978, 10840, 11685, 11686,
#         12964, 12969, 12972, 13010, 13164, 13730, 13837, 14566, 14585,
#         14604, 14647, 14786, 15178, 15289, 16176, 16244, 16708, 16828,
#         17038, 17300, 17329, 17348, 17611, 18200, 18263, 19283, 19363,
#         19491, 20436, 20499, 21422, 21498, 21721]),)

# %%
#Drop missing rows and check shape
final_df = final_df.dropna().reset_index(drop=True)
# final_df.reset_index(drop=True)
final_df.shape
# Out:
# (22100, 7)

# %%
#Number of tweets that were retweeted
Retweets = final_df[final_df['tweets'].str.contains('RT')]
Retweets['tweets'].count()
# Out:
# 7592

# %%
#Number of original tweets 
originaltweets = final_df[~final_df['tweets'].str.contains('RT')]
originaltweets['tweets'].count()
# Out:
# 14508

# %%
#https://stackoverflow.com/questions/39969089/how-to-create-pie-chart
#https://stackoverflow.com/questions/19852215/how-to-add-a-legend-to-matplotlib-pie-chart
label = ['positive','negative']
colors = ['green', 'orange'] 
plt.pie(final_df['polarity'].value_counts(),labels=label,colors=colors, startangle=90, shadow = True,
        explode = (0, 0.1), autopct = '%1.2f%%',radius=2) 
plt.show()

# %%
#https://www.geeksforgeeks.org/countplot-using-seaborn-in-python/
# Visualize the polarity counts
sns.countplot(final_df["polarity"])
plt.title("Polarity Counts")
plt.show()
# Out:
# /Users/yash/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Exclude unknown countries
countries_list = final_df[final_df.user_location_cleaned!='None']
# Select the top 10 countries
top_countries_list = countries_list["user_location_cleaned"].value_counts(sort=True).head(10)
# Visualize the top 10 countries
plt.figure(figsize=(12,10))
sns.barplot(y=top_countries_list.index,x=top_countries_list, orient="h", palette="RdYlGn")
plt.xlabel("Number of tweets")
plt.ylabel("Countries")
plt.title("Top 10 Countries")
plt.show()

# %%
#https://seaborn.pydata.org/generated/seaborn.distplot.html
# Set the seaborn style
sns.set()
#converting 'date' column to a datetime datatype
final_df['tweet_posted_on'] = pd.to_datetime(final_df['tweet_posted_on'])
# Plot the histogram of hours
sns.distplot(final_df["tweet_posted_on"].dt.hour, bins=24)
plt.title("Hourly Distribution of Tweets")
plt.show()
# Out:
# /Users/yash/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Convert 'tweet_posted_on' datatype from object to datetime format
final_df['date'] = pd.to_datetime(final_df['tweet_posted_on']).dt.date

# %%
#Visualize the polarity of tweets each day
plt.figure(figsize=(12,10))
final_df.groupby(by='date')['polarity'].mean().plot(legend=True)
plt.xlabel("Date")
plt.ylabel("Polarity")
plt.title("Tweets polarity on each day")
# Out:
# Text(0.5, 1.0, 'Tweets polarity on each day')

# %%
#https://stackoverflow.com/questions/16645799/how-to-create-a-word-cloud-from-a-corpus-in-python
positive_words =' '.join([word for word in final_df['cleaned_tweets'][final_df['polarity'] == 1]])
wordcloud = WordCloud( background_color='white',
        stopwords=stopwords.words('english'),
        max_words=200,
        max_font_size=40, 
        scale=3,
        random_state=1).generate(positive_words)
plt.figure(dpi=600)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title("Positive Words")
plt.show()

# %%
negative_words =' '.join([text for text in final_df['cleaned_tweets'][final_df['polarity'] == 0]])
wordcloud = WordCloud( background_color='white',
        stopwords=stopwords.words('english'),
        max_words=200,
        max_font_size=40, 
        scale=3,
        random_state=1).generate(negative_words)
plt.figure(dpi=600)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title("Negative Words")
plt.show()

# %%
# Create a mask for top 1 countries (by tweets count)
mask = final_df["user_location_cleaned"].isin(top_countries_list.index[:10]).values

# Create a new DataFrame only includes top10 country
top_10 = final_df.iloc[mask,:]

# Visualize the top 20 countries
plt.figure(figsize=(12,10))
sns.countplot(x="user_location_cleaned", hue="polarity", data=top_10, order=top_10["user_location_cleaned"].value_counts().index)
plt.xlabel("Countries")
locs, labels = plt.xticks()
plt.xticks(locs, top_countries_list.index)
plt.xticks(rotation=45)
plt.ylabel("Tweet count")
plt.title("Top 10 Countries")
plt.show()

# %%
def list_hashtag(tweet):
    prob = tweet.replace("#remotework","")
    prob = prob.replace("#workfromhome","")
    prob = prob.replace("#WorkFromHome","")
    prob = prob.replace("#RemoteWork","")
    prob = prob.replace("#wfh","")
    prob = prob.replace("#WFH","")
    prob = prob.replace("#Hiring","")
    prob = prob.replace("#workathome","")
    prob = prob.replace("#remotejob","")
    return prob

# %%
#https://stackoverflow.com/questions/50582305/extract-and-count-unique-hashtags-per-row-from-a-pandas-dataframe
prob_1 = final_df['tweets'].map(list_hashtag).str.extractall(r'(\#\w+)').reset_index(level=0).drop_duplicates()[0]

# %%
#visualize most frequent hashtags
plt.figure(figsize=(20,10))
prob_1.value_counts(sort=True).head(15).plot(kind='bar')
plt.xticks(rotation=0)
plt.show()
