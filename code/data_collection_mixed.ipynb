# %% [markdown]
# # Capstone Project

# %% [markdown]
# ### Data Collection

# %%
#Import libraries
import tweepy
import pandas as pd
import time

# %%
# %run ../keys.ipynb #Run the API keys

# %%
#https://www.youtube.com/watch?v=bNDRiaFyLrs
auth = tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_token_secret)
api = tweepy.API(auth,timeout=600000)

# %%
#https://docs.tweepy.org/en/stable/code_snippet.html#handling-the-rate-limit-using-cursors
#https://stackoverflow.com/questions/51700960/runtimeerror-generator-raised-stopiteration-every-time-i-try-to-run-app
def limit_handled(cursor):
    while True:
        try:
            yield cursor.next()
        except (tweepy.RateLimitError, tweepy.TweepError):
            print("sleeping")
            time.sleep(15 * 60)    
        except StopIteration:
            return

# %%
##https://docs.tweepy.org/en/latest/api.html#search-tweets
#Fetch the response for a given number of tweets where location is not null
def getTweets_by_hashTag(hashtag,num_tweets): 
    tweets = []
    user_location = []
    created_at = []
    tweet_id = []
    while(len(tweets)<num_tweets): #loop iterates until tweets length < or = to num_tweets
        for page in limit_handled(tweepy.Cursor(api.search,
                              q = hashtag,
                              tweet_mode="extended",
                              include_entities=False,
                              lang="en").pages()):
            print(f"Returning {len(page)} page size")
            for item in page:
                if item._json['user']['location'].strip(" ") != "" : #get post where "location" is not empty
                        tweets.append(item.full_text)
                        user_location.append(item._json['user']['location'])
                        created_at.append(item._json['created_at'])
                        tweet_id.append(item._json['id'])
        print(f"Returning {len(tweets)} tweets")
    tweet_df = pd.DataFrame({'tweets':tweets,'user_location':user_location,'tweet_posted_on':created_at,'tweet_id':tweet_id})        
    return tweet_df

# %% [markdown]
# ### #workfromhome Data Collection

# %%
#get tweets of '#workfromhome' and save it in a dataframe
wfh_hashtag_df1 = getTweets_by_hashTag("#workfromhome",5000)
# Out:
# sleeping
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 11 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 13 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 10 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 13 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 12 page size
# Returning 12 page size
# Returning 13 page size
# Returning 11 page size
# Returning 10 page size
# Returning 7 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 12 page size
# Returning 14 page size
# Returning 8 page size
# Returning 11 page size
# Returning 11 page size
# Returning 12 page size
# Returning 14 page size
# Returning 13 page size
# Returning 13 page size
# Returning 12 page size
# Returning 9 page size
# Returning 7 page size
# Returning 10 page size
# Returning 7 page size
# Returning 10 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 11 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 11 page size
# Returning 15 page size
# Returning 10 page size
# Returning 9 page size
# Returning 14 page size
# Returning 9 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 11 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 12 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 12 page size
# Returning 15 page size
# Returning 11 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 13 page size
# Returning 15 page size
# Returning 13 page size
# Returning 11 page size
# Returning 13 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 11 page size
# Returning 7 page size
# Returning 10 page size
# Returning 11 page size
# Returning 12 page size
# Returning 11 page size
# Returning 11 page size
# Returning 7 page size
# Returning 9 page size
# Returning 13 page size
# Returning 10 page size
# Returning 7 page size
# Returning 12 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 12 page size
# Returning 11 page size
# Returning 15 page size
# Returning 15 page size
# sleeping
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 13 page size
# Returning 12 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 11 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 12 page size
# Returning 15 page size
# Returning 15 page size
# Returning 11 page size
# Returning 9 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 10 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 12 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 14 page size
# Returning 12 page size
# Returning 9 page size
# Returning 13 page size
# Returning 8 page size
# Returning 8 page size
# Returning 9 page size
# Returning 12 page size
# Returning 11 page size
# Returning 10 page size
# Returning 12 page size
# Returning 10 page size
# Returning 11 page size
# Returning 12 page size
# Returning 12 page size
# Returning 7 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 8 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 12 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 10 page size
# Returning 13 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 12 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 12 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 11 page size
# Returning 14 page size
# Returning 15 page size
# Returning 14 page size
# Returning 11 page size
# Returning 12 page size
# Returning 10 page size
# Returning 9 page size
# Returning 9 page size
# Returning 10 page size
# Returning 15 page size
# Returning 6 page size
# Returning 10 page size
# Returning 10 page size
# Returning 12 page size
# Returning 13 page size
# Returning 9 page size
# Returning 11 page size
# Returning 13 page size
# Returning 13 page size
# Returning 8 page size
# Returning 8 page size
# sleeping
# Returning 14 page size
# Returning 13 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 13 page size
# Returning 13 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 13 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 11 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 13 page size
# Returning 12 page size
# Returning 7 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 12 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 7 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 13 page size
# Returning 13 page size
# Returning 13 page size
# Returning 12 page size
# Returning 12 page size
# Returning 13 page size
# Returning 9 page size
# Returning 9 page size
# Returning 12 page size
# Returning 11 page size
# Returning 12 page size
# Returning 11 page size
# Returning 13 page size
# Returning 11 page size
# Returning 14 page size
# Returning 15 page size
# Returning 10 page size
# Returning 6 page size
# Returning 13 page size
# Returning 13 page size
# Returning 12 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 13 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 13 page size
# Returning 13 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 13 page size
# Returning 15 page size
# Returning 14 page size
# Returning 11 page size
# Returning 13 page size
# Returning 15 page size
# Returning 11 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 12 page size
# Returning 7 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# sleeping
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 11 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 13 page size
# Returning 14 page size
# Returning 14 page size
# Returning 15 page size
# Returning 13 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 11 page size
# Returning 10 page size
# Returning 15 page size
# Returning 14 page size
# Returning 12 page size
# Returning 8 page size
# Returning 7 page size
# Returning 12 page size
# Returning 11 page size
# Returning 13 page size
# Returning 10 page size
# Returning 14 page size
# Returning 12 page size
# Returning 14 page size
# Returning 13 page size
# Returning 7 page size
# Returning 11 page size
# Returning 14 page size
# Returning 10 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 12 page size
# Returning 11 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 10 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 12 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 12 page size
# Returning 12 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 12 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 12 page size
# Returning 14 page size
# Returning 11 page size
# Returning 14 page size
# Returning 13 page size
# Returning 8 page size
# Returning 11 page size
# Returning 8 page size
# Returning 14 page size
# Returning 13 page size
# Returning 10 page size
# Returning 9 page size
# Returning 11 page size
# Returning 10 page size
# Returning 12 page size
# Returning 11 page size
# Returning 7 page size
# Returning 13 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 11 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 13 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 13 page size
# sleeping
# Returning 11 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 13 page size
# Returning 9 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 13 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 10 page size
# Returning 13 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 10 page size
# Returning 9 page size
# Returning 15 page size
# Returning 15 page size
# Returning 12 page size
# Returning 4 page size
# Returning 8 page size
# Returning 9 page size
# Returning 12 page size
# Returning 5 page size
# Returning 5 page size
# Returning 9 page size
# Returning 11 page size
# Returning 9 page size
# Returning 12 page size
# Returning 9 page size
# Returning 12 page size
# Returning 11 page size
# Returning 10 page size
# Returning 11 page size
# Returning 14 page size
# Returning 10 page size
# Returning 12 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 8 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 13 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 7615 tweets

# %%
#Display the first five rows 
wfh_hashtag_df1.head()
# Out:
#                                               tweets   user_location  \
# 0  Here are some best sites to find remote jobs. ...  United Kingdom
# 1  The Writing Mom’s Manifesto - via @pensignal #...         KY, USA
# 2  Excellent Work From Home Jobs, Where to Find T...   North America
# 3  Stop him raiding our pensions #pensionraid &am...  United Kingdom
# 4  Today's average UK #heatingoil price is 44.62p...  United Kingdom
#
#                   tweet_posted_on             tweet_id
# 0  Mon Jul 19 17:08:13 +0000 2021  1417169417587265540
# 1  Mon Jul 19 17:06:21 +0000 2021  1417168947422576643
# 2  Mon Jul 19 17:06:03 +0000 2021  1417168870348050436
# 3  Mon Jul 19 17:05:40 +0000 2021  1417168776441876483
# 4  Mon Jul 19 17:05:18 +0000 2021  1417168685341544448

# %%
#Save in a 'dataset' folder with a name 'tweet_df.csv'
wfh_hashtag_df1.to_csv('../dataset/wfh_mixed.csv')

# %% [markdown]
# ### #remotework Data Collection

# %%
#get tweets of '#remotework' and save it in a dataframe
remote_work1 = getTweets_by_hashTag("#remotework",5000)
# Out:
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 12 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 13 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 13 page size
# Returning 12 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 12 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 14 page size
# Returning 13 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 13 page size
# Returning 13 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 13 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 12 page size
# Returning 15 page size
# Returning 15 page size
# sleeping
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 10 page size
# Returning 15 page size
# Returning 8 page size
# Returning 13 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 13 page size
# Returning 11 page size
# Returning 14 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 13 page size
# Returning 14 page size
# Returning 15 page size
# Returning 14 page size
# Returning 14 page size
# Returning 14 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 13 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 12 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 14 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 12 page size
# Returning 11 page size
# Returning 12 page size
# Returning 11 page size
# Returning 15 page size
# Returning 6 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 12 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 11 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 11 page size
# Returning 13 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 7 page size
# Returning 10 page size
# Returning 12 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 12 page size
# Returning 11 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 10 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 12 page size
# Returning 9 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 13 page size
# Returning 15 page size
# Returning 13 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 9 page size
# Returning 14 page size
# Returning 15 page size
# Returning 13 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 10 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 11 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 13 page size
# Returning 9 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# sleeping
# Returning 14 page size
# Returning 12 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 13 page size
# Returning 11 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 9 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 12 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 12 page size
# Returning 15 page size
# Returning 11 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 9 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 10 page size
# Returning 13 page size
# Returning 13 page size
# Returning 14 page size
# Returning 10 page size
# Returning 13 page size
# Returning 15 page size
# Returning 13 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 11 page size
# Returning 10 page size
# Returning 13 page size
# Returning 10 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 12 page size
# Returning 15 page size
# Returning 12 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 12 page size
# Returning 9 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 13 page size
# Returning 13 page size
# Returning 13 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 14 page size
# Returning 13 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 12 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 13 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 13 page size
# Returning 11 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# sleeping
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 9 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 10 page size
# Returning 9 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 13 page size
# Returning 12 page size
# Returning 13 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 13 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 9 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 13 page size
# Returning 10 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 12 page size
# Returning 12 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 6 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 11 page size
# Returning 12 page size
# Returning 11 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# sleeping
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 12 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 13 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 12 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 12 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 12 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 14 page size
# Returning 13 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 11 page size
# Returning 12 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 6 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 8 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 12 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 12 page size
# Returning 10 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# sleeping
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 13 page size
# Returning 14 page size
# Returning 13 page size
# Returning 15 page size
# Returning 11 page size
# Returning 13 page size
# Returning 15 page size
# Returning 13 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 7 page size
# Returning 15 page size
# Returning 14 page size
# Returning 15 page size
# Returning 15 page size
# Returning 8 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 8 page size
# Returning 12 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 11 page size
# Returning 14 page size
# Returning 12 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 15 page size
# Returning 1 page size
# Returning 8776 tweets

# %%
#Display the first five rows 
remote_work1.head()
# Out:
#                                               tweets  \
# 0  RT @Humana_Careers: Your health and well-being...
# 1  Your health and well-being are our priority. W...
# 2  Introduce strong programming standards; mentor...
# 3  Remote Software Engineering Manager (Clojure T...
# 4  “What sets Otter apart is the quick and easy t...
#
#                user_location                 tweet_posted_on  \
# 0                 Everywhere  Mon Jul 19 18:12:00 +0000 2021
# 1            Louisville, KY   Mon Jul 19 18:11:55 +0000 2021
# 2          London | New York  Mon Jul 19 18:11:26 +0000 2021
# 3          London | New York  Mon Jul 19 18:08:48 +0000 2021
# 4  Mountain View, California  Mon Jul 19 18:08:05 +0000 2021
#
#               tweet_id
# 0  1417185469247500288
# 1  1417185446812082189
# 2  1417185327039537155
# 3  1417184664742207493
# 4  1417184484512907273

# %%
#Save in a 'dataset' folder with a name 'remote_work.csv'
remote_work1.to_csv('../dataset/remote_mixed.csv')
