# %%
#Import libraries
import pandas as pd
import numpy as np

# %%
#Read in 'twitter_df'
df = pd.read_csv("../dataset/twitter_df.csv")

# %%
df.drop(df[df.user_location_cleaned == 'None'].index, inplace=True)

# %%
df.to_csv('df.csv')

# %%
df[df['user_location_cleaned']=='AU']
# Out:
#        Unnamed: 0             tweet_id            tweet_posted_on  \
# 22             22  1416172472899186688  2021-07-16 23:06:43+00:00
# 864           864  1415970567354716160  2021-07-16 09:44:25+00:00
# 866           866  1415970306666033158  2021-07-16 09:43:23+00:00
# 973           973  1415919632318226432  2021-07-16 06:22:01+00:00
# 1007         1007  1415899284927508484  2021-07-16 05:01:10+00:00
# ...           ...                  ...                        ...
# 21462       21462  1419341327502807044  2021-07-25 16:58:37+00:00
# 21640       21640  1419279513352122375  2021-07-25 12:52:59+00:00
# 21698       21698  1419243160585359365  2021-07-25 10:28:32+00:00
# 21856       21856  1419134576673296386  2021-07-25 03:17:03+00:00
# 21876       21876  1419118973325479938  2021-07-25 02:15:03+00:00
#
#                                                   tweets  \
# 22     RT @MarshaCollier: Use this Goldman Sachs data...
# 864    SmartCompany: .@WhoGivesACrapTP co-founder @si...
# 866    RT @Smokeball_AU: Our clients are telling us t...
# 973    Remote work is now an everyday reality. Integr...
# 1007   Working with us will reduce your overhead, all...
# ...                                                  ...
# 21462  RT @stratorob: Success is the sum of small eff...
# 21640  RT @stratorob: Success is the sum of small eff...
# 21698  RT @codecidedotnet: The best — and worst — cit...
# 21856  Outsourcing done right can make a huge impact ...
# 21876  3 REASONS THE REMOTE WORK TREND IS HERE TO STA...
#
#                                           cleaned_tweets  \
# 22     goldman sachs data convince bos work home trav...
# 864    smartcompany founder say running remote busine...
# 866    client telling lost without smokeball right cl...
# 973    remote work everyday reality integrate busines...
# 1007   working reduce overhead allowing fund directly...
# ...                                                  ...
# 21462                      success small effort repeated
# 21640                      success small effort repeated
# 21698        best worst city remote work yahoo news http
# 21856  outsourcing done right make huge impact bottom...
# 21876  reason remote work trend stay continuous advan...
#
#                       user_location user_location_cleaned  polarity
# 22          Sydney, New South Wales                    AU         0
# 864                       Australia                    AU         0
# 866         Sydney, New South Wales                    AU         1
# 973                       Australia                    AU         1
# 1007        Australia | Philippines                    AU         1
# ...                             ...                   ...       ...
# 21462  LON | NYC | HKG  | SYD | SIN                    AU         1
# 21640  LON | NYC | HKG  | SYD | SIN                    AU         1
# 21698       Carnegie, VIC, AU, 3163                    AU         0
# 21856       Australia | Philippines                    AU         0
# 21876       Sydney, New South Wales                    AU         0
#
# [200 rows x 8 columns]
