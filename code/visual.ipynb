# %%
#Import libraries
import pandas as pd
import numpy as np

# %%
#Read in 'twitter_df'
df = pd.read_csv("../dataset/twitter_df.csv")

# %%
[df['user_location_cleaned']=='None']
# Out:
# [0        False
#  1        False
#  2        False
#  3        False
#  4        False
#           ...
#  22148     True
#  22149    False
#  22150     True
#  22151    False
#  22152    False
#  Name: user_location_cleaned, Length: 22153, dtype: bool]

# %%
df.drop(df[df.user_location_cleaned == 'None'].index, inplace=True)

# %%
df.to_csv('df.csv')

# %%
df[df['user_location_cleaned']=='GB']
# Out:
#        Unnamed: 0             tweet_id            tweet_posted_on  \
# 9               9  1416176967259500545  2021-07-16 23:24:34+00:00
# 26             26  1416170880993005574  2021-07-16 23:00:23+00:00
# 36             36  1416168270697222146  2021-07-16 22:50:01+00:00
# 69             69  1416157013193723905  2021-07-16 22:05:17+00:00
# 74             74  1416155784405295114  2021-07-16 22:00:24+00:00
# ...           ...                  ...                        ...
# 22087       22087  1418991433143488512  2021-07-24 17:48:15+00:00
# 22098       22098  1418981342361104385  2021-07-24 17:08:10+00:00
# 22102       22102  1418977803433877513  2021-07-24 16:54:06+00:00
# 22104       22104  1418977411950055428  2021-07-24 16:52:32+00:00
# 22139       22139  1418966927653933064  2021-07-24 16:10:53+00:00
#
#                                                   tweets  \
# 9      The latest update for #Axosoft includes "#GitK...
# ...
